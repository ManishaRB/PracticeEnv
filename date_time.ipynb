# %% [markdown]
# # Date Time Overview

# %%
#importing datetime module
import datetime
from datetime import date, datetime, time

# %%
lastweek = date(2026, 4, 22)
print(lastweek)
# Out:
# 2026-04-22

# %%
today = date.today()
print(today)
# Out:
# 2026-04-29

# %%
print(today - lastweek)
# Out:
# 7 days, 0:00:00

# %%
right_now = datetime.now()
print(right_now)
# Out:
# 2026-04-29 10:41:41.781417

# %%
time_right_now = time(9, 0, 0)
print(time_right_now)
# Out:
# 09:00:00

# %%
# strftime() - string format time - reformats time as a string
print(today.strftime('%A %B %d %Y'))
print(date.today().strftime('%A %B %d %Y'))
# Out:
# Wednesday April 29 2026
# Wednesday April 29 2026
